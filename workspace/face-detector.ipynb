# %% [markdown]
# #   Face detection
#
# <centre>![do something](https://miro.medium.com/max/1024/1*I8XBP5TQrAFCBW_jQZBbZw.jpeg)</centre>
#
# <br/>
# in computer vision is the field where human try to teach computers how to understand and get information from images by using many techniques of deep learning, there are a lot of implimentation for this, like object detection, object classification, text detection....etc
#
# **object detection** is one of the hardest problems, it consiste of 2 steps, detecting the object in other word, try to detect the location of objects in an image that contains a lot of objects, and try to classify this detected obeject, many algorthim were detected for this, like **R-CNN** and **Fast R-CNN** which is an improved version of the first one, but it still slow and can't really be used in realy time detection then they created **YOLO** (You Only Look Once) algorith that overperform the R-CNN  and many other algorithms.
#
# in our problem of face detection it's the same logic that can be used to solve it, one network or algorithm to detect the face area and another network to detect if it's a face or not.
#
# we won't go till the real time detection, but we will train our own classifier, then try to create a **window sliding** algorithm that can detect the face's area.
#
#
# so in the cell below you can find the different secions of our notebook

# %% [markdown]
# 1. **[Load the data](#load)**
# 2. **[visualization of our data](#print)**
# 3. **[model and training tools](#model)**
# 4. **[Window SLider](#window)**

# %% [markdown]
# # <a id='load'>loading the data</a>
#
# the first step of any learning algorithm is to load your data. and print some simples so you can have an idea about it, and know what you will  do next (data augmentation,cleaning...etc) or just move to learning step. in our loading data algorithm we will make it so clean by using only dicts so when we want to change anything it would be so simple
#
# but after that we will import some useful libraries

# %%
import torch
import torchvision
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data.sampler import SubsetRandomSampler

# %%
import os

# create transforms in this case we will applay Random rotation on our data, then we resize our images to 64 * 64 and all that we will be transferred to a tansors than normalized
images_transform = {'train':transforms.Compose([transforms.RandomRotation(20),
                                                transforms.RandomCrop((16,16)),
                                               
                                                transforms.Resize((64,64)),
                                                transforms.Grayscale(num_output_channels = 1),
                                                transforms.ToTensor(),
                                ]),
                    'test':transforms.Compose([ transforms.Resize((64,64)),
                                                transforms.Grayscale(num_output_channels = 1),
                                                transforms.ToTensor(),
                                ])
                   
                   }

# we save the data dirs in the a dict to use it after

images_dir = { 
                'train': '../input/somefaces/data/train_images',
                'test': '../input/somefaces/data/test_images'
             }


## we load the data and transform it using our transform
images_data = { 'train': torchvision.datasets.ImageFolder(images_dir['train'],transform=images_transform['train']),
                'test': torchvision.datasets.ImageFolder(images_dir['test'],transform=images_transform['test'])
              }

### in our case i will split the training data into 3 subsets  a train, validation and another test set because i think that the test set that we have is not enough .
# first we calculate the data that we have (we won't have the exact number because we did some data augmentation, but it's okay we don't need to have the exact number)
number_train_data = len(os.listdir('../input/somefaces/data/train_images/1')) + len(os.listdir('../input/somefaces/data/train_images/0')) 
# we create a list of indices 
indices = np.arange(number_train_data)
# we shuffle it
np.random.shuffle(indices)

# we calculate the validationset's size and it will be the same size as the test_2 (2nd version of testset)
valid_size = int(0.35 *  number_train_data)

# we create our laoders 
data_loaders = { 'train': torch.utils.data.DataLoader(images_data['train'],batch_size = 32,sampler=SubsetRandomSampler(indices[2 * valid_size:])),
                 'valid': torch.utils.data.DataLoader(images_data['train'],batch_size = 32,sampler=SubsetRandomSampler(indices[:valid_size])),  
                 'test_1': torch.utils.data.DataLoader(images_data['test'],batch_size = 32,shuffle=True),             
                 'test_2': torch.utils.data.DataLoader(images_data['train'],batch_size = 32,sampler=SubsetRandomSampler(indices[valid_size: 2* valid_size]))
               }

# %% [markdown]
# # <a id='print'>visualization of our data</a>
#
# this is an important step of any similar problem, seeing the data (seeing the images, ploting your data if they are numbers, see some correlation tables...etc ) this can give u an idea about what is wrong with your data (if anything is wrong of course), what you should do next what kind of cleaning or augmentation do you need and what is the best algorith to use and many other informations

# %%
def visulize(data):
        plt.subplot(1, 3, 1)
        plt.imshow(data[0][0].squeeze(), cmap='gray')
        plt.subplot(1,3,2)
        plt.imshow(data[0][2].squeeze(), cmap='gray')
        plt.subplot(1,3,3)
        plt.imshow(data[0][3].squeeze(), cmap='gray')

# %%
iterate = iter(data_loaders['train'])
visulize(next(iterate))

# %%
iterate = iter(data_loaders['test_1'])
visulize(next(iterate))

# %%
iterate = iter(data_loaders['test_2'])
visulize(next(iterate))

# %% [markdown]
# we see that our data looks good (not for human but hoping it's good for computers ;) ), there is a 20 degrees rotation in some images, most of images don't look okay  because of the normalization that we made
#
# now it's time for talking deep learning
# so let's creat our model and some function for trianing and testing

# %% [markdown]
# # <a id="model"> model and training tools</a>

# %% [markdown]
# so in this part we will try to  build our model, train it and see how well we did, maybe change the model and trian again and so on till we get a model that predict well

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        ## ----------------Convolution layer
        self.conv_1 = nn.Conv2d(1,6,kernel_size = 3, stride = 2)
        self.conv_2 = nn.Conv2d(6,6,kernel_size = 3, stride = 2)        
        self.conv_3 = nn.Conv2d(6,3,kernel_size = 3, stride = 2)   
        
        ##---------------- pooling layers
        
        self.pooling = nn.MaxPool2d(kernel_size = 2, stride = 2, padding = 0)
        # calculate the output from the conv layers
        self.fc_input_size = 3*3*3
        
        ##--------------- fully connected layers
        self.fc1 = nn.Linear(self.fc_input_size,64)
        self.fc2 = nn.Linear(64,128)
        self.fc3 = nn.Linear(128,2)
        ## create a dropout with p=0.15
        self.dropout = nn.Dropout(p = 0.15)
    

    def forward(self, x):
        # conv 1
        x = self.conv_1(x)
        x = F.relu(x)
        # conv 2
        x = self.conv_2(x)
        x = F.relu(x)
        
        x = self.pooling(x)
        # conv 3
        x = self.conv_3(x)
        x = F.relu(x)
        
        ### transform the output of the last layer to a  vector
        
        x = x.view(-1,self.fc_input_size)
        
        
        # fully connnected 1
        x = self.fc1(x)
        x = self.dropout(x)
        x = F.relu(x)
        
        # fully connnected 2
        x = self.fc2(x)
        x = self.dropout(x)
        x = F.relu(x)
        
        
        # output 
        x = self.fc3(x)
        x = F.softmax(x,dim=1)
        return x

# %% [markdown]
# in human logic we train than we test, we lean than we have exams, but in this case we will define a test function first than the training function, because we will need the test function in the training function.

# %%
# before we define anything we will let our model know in what device we are working on now, if it's GPU (it will be happy if it is), or a simple poor CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def testing(model = None,testloader = None,criterion = None, print_accuracy = False):
    correct = 0
    total = 0
    loss = 0
    more_statistic = {0:{0:0,1:0},1:{0:0,1:0}}
    with torch.no_grad():
        for data in testloader:
            inputs, labels = data

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            result = model(inputs)
            loss += criterion(result,labels)
            _,predicted = torch.max(result.data, 1)
            for i in range(len(predicted)):
                more_statistic[int(labels[i])][int(predicted[i])] += 1
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    if print_accuracy:
        print('Accurcy is :: {:.2f}' .format(100 * correct / total))
    return loss.item() , (100 * correct / total),more_statistic

# %%
def trianing(epochs = 100,model = None,criterion = None, optimizer = None, train_loader = None,valid_loader = None,saved_file_name = "checkpoint_v10.pth"):
    train_losses = list()
    valid_losses = list()
    min_loss = 1e6
    total = 0
    counter = 0
    for epoch in range(epochs):
        if counter == 40:
            print('{} epochs without any changes it means we are iin the overfitting phase \n \t bey bey')
            break
        epoch_loss = 0
        for i,data in enumerate(train_loader,1):
           
            
            inputs, labels = data
            
            if epoch == 0:
                total += labels.size(0)
            
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad()
            result = model(inputs)
            loss = criterion(result,labels)
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            
        train_losses.append(epoch_loss)
        validation_loss,_,__ = testing(model = model,testloader = valid_loader,criterion = criterion)
        valid_losses.append(validation_loss)
        counter += 1
        print('Epoch {}\t train loss :: {:.2f} and the validation loss is ::{:.2f}'.format(epoch, epoch_loss,validation_loss))
        if min_loss > validation_loss:
            counter = 0
            min_loss = validation_loss
            print('#------------------  saving the model in {} epoch with validation loss :: {:.2f}'.format(epoch,validation_loss))
            torch.save(model.state_dict(),saved_file_name)
    return train_losses,valid_losses

# %% [markdown]
# and here it cames the learning phase, it will take a very long time even on GPU because we have like a really big number of images

# %%
import torch.optim as optim
model_v1 = Net().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_v1.parameters(),lr = 1e-4)

# %%
saved_file_name = "checkpoint.pth"
train_loss,valid_loss = trianing(epochs = 350,
         model = model_v1,
         criterion = criterion,
         optimizer = optimizer, 
         train_loader = data_loaders['train'],
         valid_loader = data_loaders['valid'],
         saved_file_name = saved_file_name)
# Out:
# Epoch 0	 train loss :: 524.14 and the validation loss is ::582.94
# #------------------  saving the model in 0 epoch with validation loss :: 582.94
# Epoch 1	 train loss :: 469.83 and the validation loss is ::521.65
# #------------------  saving the model in 1 epoch with validation loss :: 521.65
# Epoch 2	 train loss :: 442.66 and the validation loss is ::518.67
# #------------------  saving the model in 2 epoch with validation loss :: 518.67
# Epoch 3	 train loss :: 439.40 and the validation loss is ::510.74
# #------------------  saving the model in 3 epoch with validation loss :: 510.74
# Epoch 4	 train loss :: 437.25 and the validation loss is ::511.22
# Epoch 5	 train loss :: 436.00 and the validation loss is ::509.81
# #------------------  saving the model in 5 epoch with validation loss :: 509.81
# Epoch 6	 train loss :: 435.41 and the validation loss is ::508.27
# #------------------  saving the model in 6 epoch with validation loss :: 508.27
# Epoch 7	 train loss :: 434.94 and the validation loss is ::507.11
# #------------------  saving the model in 7 epoch with validation loss :: 507.11
# Epoch 8	 train loss :: 434.91 and the validation loss is ::506.73
# #------------------  saving the model in 8 epoch with validation loss :: 506.73
# Epoch 9	 train loss :: 433.48 and the validation loss is ::506.89
# Epoch 10	 train loss :: 433.01 and the validation loss is ::504.25
# #------------------  saving the model in 10 epoch with validation loss :: 504.25
# Epoch 11	 train loss :: 432.59 and the validation loss is ::504.20
# #------------------  saving the model in 11 epoch with validation loss :: 504.20
# Epoch 12	 train loss :: 431.15 and the validation loss is ::501.69
# #------------------  saving the model in 12 epoch with validation loss :: 501.69
# Epoch 13	 train loss :: 431.19 and the validation loss is ::503.94
# Epoch 14	 train loss :: 430.36 and the validation loss is ::504.91
# Epoch 15	 train loss :: 430.02 and the validation loss is ::501.71
# Epoch 16	 train loss :: 428.68 and the validation loss is ::504.69
# Epoch 17	 train loss :: 427.27 and the validation loss is ::498.83
# #------------------  saving the model in 17 epoch with validation loss :: 498.83
# Epoch 18	 train loss :: 427.95 and the validation loss is ::496.91
# #------------------  saving the model in 18 epoch with validation loss :: 496.91
# Epoch 19	 train loss :: 425.57 and the validation loss is ::495.22
# #------------------  saving the model in 19 epoch with validation loss :: 495.22
# Epoch 20	 train loss :: 424.83 and the validation loss is ::502.72
# Epoch 21	 train loss :: 424.18 and the validation loss is ::493.01
# #------------------  saving the model in 21 epoch with validation loss :: 493.01
# Epoch 22	 train loss :: 424.32 and the validation loss is ::493.61
# Epoch 23	 train loss :: 423.04 and the validation loss is ::497.37
# Epoch 24	 train loss :: 422.91 and the validation loss is ::494.67
# Epoch 25	 train loss :: 422.27 and the validation loss is ::490.66
# #------------------  saving the model in 25 epoch with validation loss :: 490.66
# Epoch 26	 train loss :: 419.21 and the validation loss is ::496.81
# Epoch 27	 train loss :: 420.30 and the validation loss is ::489.68
# #------------------  saving the model in 27 epoch with validation loss :: 489.68
# Epoch 28	 train loss :: 420.92 and the validation loss is ::489.02
# #------------------  saving the model in 28 epoch with validation loss :: 489.02
# Epoch 29	 train loss :: 418.81 and the validation loss is ::492.06
# Epoch 30	 train loss :: 419.10 and the validation loss is ::491.28
# Epoch 31	 train loss :: 417.66 and the validation loss is ::494.18
# Epoch 32	 train loss :: 418.71 and the validation loss is ::485.47
# #------------------  saving the model in 32 epoch with validation loss :: 485.47
# Epoch 33	 train loss :: 417.80 and the validation loss is ::485.25
# #------------------  saving the model in 33 epoch with validation loss :: 485.25
# Epoch 34	 train loss :: 417.34 and the validation loss is ::486.33
# Epoch 35	 train loss :: 417.61 and the validation loss is ::484.62
# #------------------  saving the model in 35 epoch with validation loss :: 484.62
# Epoch 36	 train loss :: 416.47 and the validation loss is ::489.13
# Epoch 37	 train loss :: 414.44 and the validation loss is ::486.43
# Epoch 38	 train loss :: 415.76 and the validation loss is ::513.43
# Epoch 39	 train loss :: 417.76 and the validation loss is ::485.91
# Epoch 40	 train loss :: 412.87 and the validation loss is ::483.71
# #------------------  saving the model in 40 epoch with validation loss :: 483.71
# Epoch 41	 train loss :: 416.90 and the validation loss is ::482.16
# #------------------  saving the model in 41 epoch with validation loss :: 482.16
# Epoch 42	 train loss :: 417.37 and the validation loss is ::482.03
# #------------------  saving the model in 42 epoch with validation loss :: 482.03
# Epoch 43	 train loss :: 415.14 and the validation loss is ::482.99
# Epoch 44	 train loss :: 415.83 and the validation loss is ::481.11
# #------------------  saving the model in 44 epoch with validation loss :: 481.11
# Epoch 45	 train loss :: 415.28 and the validation loss is ::480.02
# #------------------  saving the model in 45 epoch with validation loss :: 480.02
# Epoch 46	 train loss :: 413.80 and the validation loss is ::489.02
# Epoch 47	 train loss :: 413.62 and the validation loss is ::482.40
# Epoch 48	 train loss :: 413.33 and the validation loss is ::480.56
# Epoch 49	 train loss :: 411.85 and the validation loss is ::480.08
# Epoch 50	 train loss :: 414.36 and the validation loss is ::479.63
# #------------------  saving the model in 50 epoch with validation loss :: 479.63
# Epoch 51	 train loss :: 414.98 and the validation loss is ::479.65
# Epoch 52	 train loss :: 412.72 and the validation loss is ::478.73
# #------------------  saving the model in 52 epoch with validation loss :: 478.73
# Epoch 53	 train loss :: 411.74 and the validation loss is ::479.64
# Epoch 54	 train loss :: 411.02 and the validation loss is ::479.69
# Epoch 55	 train loss :: 412.95 and the validation loss is ::479.45
# Epoch 56	 train loss :: 414.52 and the validation loss is ::482.60
# Epoch 57	 train loss :: 414.77 and the validation loss is ::497.73
# Epoch 58	 train loss :: 411.61 and the validation loss is ::477.55
# #------------------  saving the model in 58 epoch with validation loss :: 477.55
# Epoch 59	 train loss :: 410.73 and the validation loss is ::482.32
# Epoch 60	 train loss :: 412.24 and the validation loss is ::477.04
# #------------------  saving the model in 60 epoch with validation loss :: 477.04
# Epoch 61	 train loss :: 412.59 and the validation loss is ::478.33
# Epoch 62	 train loss :: 411.50 and the validation loss is ::475.44
# #------------------  saving the model in 62 epoch with validation loss :: 475.44
# Epoch 63	 train loss :: 411.57 and the validation loss is ::480.11
# Epoch 64	 train loss :: 410.89 and the validation loss is ::477.08
# Epoch 65	 train loss :: 412.69 and the validation loss is ::477.65
# Epoch 66	 train loss :: 410.42 and the validation loss is ::477.21
# Epoch 67	 train loss :: 411.67 and the validation loss is ::477.65
# Epoch 68	 train loss :: 409.85 and the validation loss is ::476.82
# Epoch 69	 train loss :: 410.50 and the validation loss is ::487.06
# Epoch 70	 train loss :: 410.47 and the validation loss is ::477.25
# Epoch 71	 train loss :: 409.15 and the validation loss is ::475.16
# #------------------  saving the model in 71 epoch with validation loss :: 475.16
# Epoch 72	 train loss :: 411.83 and the validation loss is ::478.48
# Epoch 73	 train loss :: 409.62 and the validation loss is ::474.76
# #------------------  saving the model in 73 epoch with validation loss :: 474.76
# Epoch 74	 train loss :: 410.29 and the validation loss is ::478.22
# Epoch 75	 train loss :: 410.56 and the validation loss is ::473.05
# #------------------  saving the model in 75 epoch with validation loss :: 473.05
# Epoch 76	 train loss :: 409.37 and the validation loss is ::474.58
# Epoch 77	 train loss :: 408.92 and the validation loss is ::486.45
# Epoch 78	 train loss :: 408.76 and the validation loss is ::476.87
# Epoch 79	 train loss :: 407.87 and the validation loss is ::491.03
# Epoch 80	 train loss :: 410.82 and the validation loss is ::473.44
# Epoch 81	 train loss :: 409.07 and the validation loss is ::478.34
# Epoch 82	 train loss :: 408.84 and the validation loss is ::477.07
# Epoch 83	 train loss :: 407.57 and the validation loss is ::476.51
# Epoch 84	 train loss :: 408.37 and the validation loss is ::475.26
# Epoch 85	 train loss :: 407.59 and the validation loss is ::475.70
# Epoch 86	 train loss :: 406.53 and the validation loss is ::475.25
# Epoch 87	 train loss :: 408.93 and the validation loss is ::473.84
# Epoch 88	 train loss :: 407.86 and the validation loss is ::470.97
# #------------------  saving the model in 88 epoch with validation loss :: 470.97
# Epoch 89	 train loss :: 408.95 and the validation loss is ::475.75
# Epoch 90	 train loss :: 408.96 and the validation loss is ::481.98
# Epoch 91	 train loss :: 407.40 and the validation loss is ::481.06
# Epoch 92	 train loss :: 408.87 and the validation loss is ::472.44
# Epoch 93	 train loss :: 408.01 and the validation loss is ::477.02
# Epoch 94	 train loss :: 406.18 and the validation loss is ::476.91
# Epoch 95	 train loss :: 406.93 and the validation loss is ::479.30
# Epoch 96	 train loss :: 405.93 and the validation loss is ::473.63
# Epoch 97	 train loss :: 407.38 and the validation loss is ::474.00
# Epoch 98	 train loss :: 407.61 and the validation loss is ::474.33
# Epoch 99	 train loss :: 406.62 and the validation loss is ::476.65
# Epoch 100	 train loss :: 406.73 and the validation loss is ::476.82
# Epoch 101	 train loss :: 407.08 and the validation loss is ::476.66
# Epoch 102	 train loss :: 408.18 and the validation loss is ::481.79
# Epoch 103	 train loss :: 407.56 and the validation loss is ::477.19
# Epoch 104	 train loss :: 407.32 and the validation loss is ::471.11
# Epoch 105	 train loss :: 404.10 and the validation loss is ::470.86
# #------------------  saving the model in 105 epoch with validation loss :: 470.86
# Epoch 106	 train loss :: 406.16 and the validation loss is ::478.70
# Epoch 107	 train loss :: 406.86 and the validation loss is ::479.31
# Epoch 108	 train loss :: 406.33 and the validation loss is ::469.32
# #------------------  saving the model in 108 epoch with validation loss :: 469.32
# Epoch 109	 train loss :: 407.48 and the validation loss is ::475.26
# Epoch 110	 train loss :: 405.80 and the validation loss is ::471.80
# Epoch 111	 train loss :: 404.97 and the validation loss is ::474.90
# Epoch 112	 train loss :: 407.88 and the validation loss is ::474.54
# Epoch 113	 train loss :: 407.06 and the validation loss is ::475.10
# Epoch 114	 train loss :: 406.39 and the validation loss is ::468.88
# #------------------  saving the model in 114 epoch with validation loss :: 468.88
# Epoch 115	 train loss :: 405.62 and the validation loss is ::468.57
# #------------------  saving the model in 115 epoch with validation loss :: 468.57
# Epoch 116	 train loss :: 403.78 and the validation loss is ::474.35
# Epoch 117	 train loss :: 405.52 and the validation loss is ::480.08
# Epoch 118	 train loss :: 406.00 and the validation loss is ::481.28
# Epoch 119	 train loss :: 404.38 and the validation loss is ::480.14
# Epoch 120	 train loss :: 404.78 and the validation loss is ::468.75
# Epoch 121	 train loss :: 404.59 and the validation loss is ::479.11
# Epoch 122	 train loss :: 403.31 and the validation loss is ::470.47
# Epoch 123	 train loss :: 403.29 and the validation loss is ::480.17
# Epoch 124	 train loss :: 403.44 and the validation loss is ::487.54
# Epoch 125	 train loss :: 405.43 and the validation loss is ::470.55
# Epoch 126	 train loss :: 405.51 and the validation loss is ::475.95
# Epoch 127	 train loss :: 404.83 and the validation loss is ::467.32
# #------------------  saving the model in 127 epoch with validation loss :: 467.32
# Epoch 128	 train loss :: 404.73 and the validation loss is ::477.54
# Epoch 129	 train loss :: 403.89 and the validation loss is ::467.44
# Epoch 130	 train loss :: 405.56 and the validation loss is ::469.39
# Epoch 131	 train loss :: 404.92 and the validation loss is ::467.20
# #------------------  saving the model in 131 epoch with validation loss :: 467.20
# Epoch 132	 train loss :: 402.87 and the validation loss is ::472.53
# Epoch 133	 train loss :: 405.19 and the validation loss is ::467.51
# Epoch 134	 train loss :: 405.09 and the validation loss is ::478.65
# Epoch 135	 train loss :: 402.65 and the validation loss is ::470.84
# Epoch 136	 train loss :: 403.85 and the validation loss is ::467.47
# Epoch 137	 train loss :: 405.55 and the validation loss is ::489.54
# Epoch 138	 train loss :: 403.80 and the validation loss is ::466.66
# #------------------  saving the model in 138 epoch with validation loss :: 466.66
# Epoch 139	 train loss :: 402.84 and the validation loss is ::469.69
# Epoch 140	 train loss :: 402.35 and the validation loss is ::467.70
# Epoch 141	 train loss :: 403.47 and the validation loss is ::467.04
# Epoch 142	 train loss :: 404.60 and the validation loss is ::465.22
# #------------------  saving the model in 142 epoch with validation loss :: 465.22
# Epoch 143	 train loss :: 402.81 and the validation loss is ::469.20
# Epoch 144	 train loss :: 403.06 and the validation loss is ::470.96
# Epoch 145	 train loss :: 404.46 and the validation loss is ::467.70
# Epoch 146	 train loss :: 404.04 and the validation loss is ::470.02
# Epoch 147	 train loss :: 404.59 and the validation loss is ::472.11
# Epoch 148	 train loss :: 402.28 and the validation loss is ::468.67
# Epoch 149	 train loss :: 403.46 and the validation loss is ::467.81
# Epoch 150	 train loss :: 401.24 and the validation loss is ::467.08
# Epoch 151	 train loss :: 400.91 and the validation loss is ::486.35
# Epoch 152	 train loss :: 403.70 and the validation loss is ::467.37
# Epoch 153	 train loss :: 402.26 and the validation loss is ::478.98
# Epoch 154	 train loss :: 402.31 and the validation loss is ::470.83
# Epoch 155	 train loss :: 402.22 and the validation loss is ::467.05
# Epoch 156	 train loss :: 401.31 and the validation loss is ::482.50
# Epoch 157	 train loss :: 401.44 and the validation loss is ::467.56
# Epoch 158	 train loss :: 402.37 and the validation loss is ::470.29
# Epoch 159	 train loss :: 401.14 and the validation loss is ::466.54
# Epoch 160	 train loss :: 402.28 and the validation loss is ::465.42
# Epoch 161	 train loss :: 402.95 and the validation loss is ::467.90
# Epoch 162	 train loss :: 401.43 and the validation loss is ::469.07
# Epoch 163	 train loss :: 402.06 and the validation loss is ::466.97
# Epoch 164	 train loss :: 402.78 and the validation loss is ::475.00
# Epoch 165	 train loss :: 401.00 and the validation loss is ::469.02
# Epoch 166	 train loss :: 401.59 and the validation loss is ::467.45
# Epoch 167	 train loss :: 401.76 and the validation loss is ::478.50
# Epoch 168	 train loss :: 401.35 and the validation loss is ::468.36
# Epoch 169	 train loss :: 403.72 and the validation loss is ::464.62
# #------------------  saving the model in 169 epoch with validation loss :: 464.62
# Epoch 170	 train loss :: 401.97 and the validation loss is ::466.44
# Epoch 171	 train loss :: 403.07 and the validation loss is ::471.99
# Epoch 172	 train loss :: 403.03 and the validation loss is ::464.78
# Epoch 173	 train loss :: 400.58 and the validation loss is ::467.21
# Epoch 174	 train loss :: 401.16 and the validation loss is ::465.56
# Epoch 175	 train loss :: 399.04 and the validation loss is ::465.28
# Epoch 176	 train loss :: 403.11 and the validation loss is ::467.51
# Epoch 177	 train loss :: 401.73 and the validation loss is ::464.14
# #------------------  saving the model in 177 epoch with validation loss :: 464.14
# Epoch 178	 train loss :: 400.03 and the validation loss is ::470.73
# Epoch 179	 train loss :: 400.97 and the validation loss is ::474.19
# Epoch 180	 train loss :: 401.03 and the validation loss is ::466.37
# Epoch 181	 train loss :: 399.50 and the validation loss is ::475.30
# Epoch 182	 train loss :: 400.31 and the validation loss is ::465.88
# Epoch 183	 train loss :: 397.45 and the validation loss is ::465.32
# Epoch 184	 train loss :: 401.34 and the validation loss is ::462.52
# #------------------  saving the model in 184 epoch with validation loss :: 462.52
# Epoch 185	 train loss :: 399.60 and the validation loss is ::466.30
# Epoch 186	 train loss :: 398.62 and the validation loss is ::464.16
# Epoch 187	 train loss :: 400.40 and the validation loss is ::464.29
# Epoch 188	 train loss :: 400.97 and the validation loss is ::462.47
# #------------------  saving the model in 188 epoch with validation loss :: 462.47
# Epoch 189	 train loss :: 397.31 and the validation loss is ::463.69
# Epoch 190	 train loss :: 399.59 and the validation loss is ::465.01
# Epoch 191	 train loss :: 400.30 and the validation loss is ::466.07
# Epoch 192	 train loss :: 400.14 and the validation loss is ::476.86
# Epoch 193	 train loss :: 400.41 and the validation loss is ::470.10
# Epoch 194	 train loss :: 398.52 and the validation loss is ::472.81
# Epoch 195	 train loss :: 398.99 and the validation loss is ::467.37
# Epoch 196	 train loss :: 399.11 and the validation loss is ::462.50
# Epoch 197	 train loss :: 397.60 and the validation loss is ::466.35
# Epoch 198	 train loss :: 399.42 and the validation loss is ::460.74
# #------------------  saving the model in 198 epoch with validation loss :: 460.74
# Epoch 199	 train loss :: 399.33 and the validation loss is ::467.78
# Epoch 200	 train loss :: 399.81 and the validation loss is ::477.95
# Epoch 201	 train loss :: 399.67 and the validation loss is ::462.23
# Epoch 202	 train loss :: 399.55 and the validation loss is ::463.96
# Epoch 203	 train loss :: 399.08 and the validation loss is ::463.53
# Epoch 204	 train loss :: 398.27 and the validation loss is ::460.76
# Epoch 205	 train loss :: 398.49 and the validation loss is ::462.38
# Epoch 206	 train loss :: 399.97 and the validation loss is ::465.57
# Epoch 207	 train loss :: 398.54 and the validation loss is ::465.45
# Epoch 208	 train loss :: 397.91 and the validation loss is ::460.14
# #------------------  saving the model in 208 epoch with validation loss :: 460.14
# Epoch 209	 train loss :: 398.34 and the validation loss is ::465.31
# Epoch 210	 train loss :: 402.32 and the validation loss is ::461.17
# Epoch 211	 train loss :: 396.05 and the validation loss is ::461.36
# Epoch 212	 train loss :: 399.11 and the validation loss is ::470.63
# Epoch 213	 train loss :: 397.89 and the validation loss is ::478.50
# Epoch 214	 train loss :: 399.70 and the validation loss is ::467.84
# Epoch 215	 train loss :: 397.31 and the validation loss is ::473.79
# Epoch 216	 train loss :: 400.29 and the validation loss is ::461.70
# Epoch 217	 train loss :: 398.92 and the validation loss is ::468.97
# Epoch 218	 train loss :: 399.22 and the validation loss is ::464.66
# Epoch 219	 train loss :: 397.08 and the validation loss is ::460.84
# Epoch 220	 train loss :: 398.07 and the validation loss is ::461.72
# Epoch 221	 train loss :: 395.47 and the validation loss is ::460.70
# Epoch 222	 train loss :: 397.85 and the validation loss is ::483.12
# Epoch 223	 train loss :: 398.12 and the validation loss is ::473.29
# Epoch 224	 train loss :: 397.32 and the validation loss is ::467.66
# Epoch 225	 train loss :: 397.07 and the validation loss is ::465.74
# Epoch 226	 train loss :: 397.39 and the validation loss is ::474.54
# Epoch 227	 train loss :: 398.66 and the validation loss is ::461.73
# Epoch 228	 train loss :: 398.71 and the validation loss is ::463.28
# Epoch 229	 train loss :: 396.79 and the validation loss is ::469.64
# Epoch 230	 train loss :: 396.79 and the validation loss is ::461.24
# Epoch 231	 train loss :: 396.98 and the validation loss is ::474.48
# Epoch 232	 train loss :: 397.33 and the validation loss is ::459.02
# #------------------  saving the model in 232 epoch with validation loss :: 459.02
# Epoch 233	 train loss :: 397.31 and the validation loss is ::460.05
# Epoch 234	 train loss :: 394.86 and the validation loss is ::461.35
# Epoch 235	 train loss :: 397.68 and the validation loss is ::462.40
# Epoch 236	 train loss :: 395.84 and the validation loss is ::461.57
# Epoch 237	 train loss :: 397.38 and the validation loss is ::457.49
# #------------------  saving the model in 237 epoch with validation loss :: 457.49
# Epoch 238	 train loss :: 394.68 and the validation loss is ::461.36
# Epoch 239	 train loss :: 398.40 and the validation loss is ::459.00
# Epoch 240	 train loss :: 397.26 and the validation loss is ::460.15
# Epoch 241	 train loss :: 395.51 and the validation loss is ::467.13
# Epoch 242	 train loss :: 396.35 and the validation loss is ::458.46
# Epoch 243	 train loss :: 397.38 and the validation loss is ::480.37
# Epoch 244	 train loss :: 395.82 and the validation loss is ::464.97
# Epoch 245	 train loss :: 393.88 and the validation loss is ::462.52
# Epoch 246	 train loss :: 392.97 and the validation loss is ::465.92
# Epoch 247	 train loss :: 396.16 and the validation loss is ::463.73
# Epoch 248	 train loss :: 395.20 and the validation loss is ::460.58
# Epoch 249	 train loss :: 396.00 and the validation loss is ::458.70
# Epoch 250	 train loss :: 394.42 and the validation loss is ::460.08
# Epoch 251	 train loss :: 395.28 and the validation loss is ::462.63
# Epoch 252	 train loss :: 395.18 and the validation loss is ::458.65
# Epoch 253	 train loss :: 397.14 and the validation loss is ::457.21
# #------------------  saving the model in 253 epoch with validation loss :: 457.21
# Epoch 254	 train loss :: 396.01 and the validation loss is ::457.78
# Epoch 255	 train loss :: 396.36 and the validation loss is ::464.93
# Epoch 256	 train loss :: 395.71 and the validation loss is ::471.22
# Epoch 257	 train loss :: 393.76 and the validation loss is ::462.59
# Epoch 258	 train loss :: 395.34 and the validation loss is ::457.52
# Epoch 259	 train loss :: 395.65 and the validation loss is ::463.65
# Epoch 260	 train loss :: 395.64 and the validation loss is ::468.70
# Epoch 261	 train loss :: 394.10 and the validation loss is ::458.36
# Epoch 262	 train loss :: 395.68 and the validation loss is ::462.85
# Epoch 263	 train loss :: 396.53 and the validation loss is ::467.43
# Epoch 264	 train loss :: 394.31 and the validation loss is ::464.35
# Epoch 265	 train loss :: 396.54 and the validation loss is ::457.40
# Epoch 266	 train loss :: 394.33 and the validation loss is ::465.64
# Epoch 267	 train loss :: 394.80 and the validation loss is ::462.00
# Epoch 268	 train loss :: 393.18 and the validation loss is ::465.49
# Epoch 269	 train loss :: 396.28 and the validation loss is ::464.41
# Epoch 270	 train loss :: 393.65 and the validation loss is ::457.62
# Epoch 271	 train loss :: 393.46 and the validation loss is ::466.55
# Epoch 272	 train loss :: 395.06 and the validation loss is ::458.96
# Epoch 273	 train loss :: 392.25 and the validation loss is ::457.94
# Epoch 274	 train loss :: 396.94 and the validation loss is ::457.30
# Epoch 275	 train loss :: 391.63 and the validation loss is ::468.83
# Epoch 276	 train loss :: 394.62 and the validation loss is ::466.60
# Epoch 277	 train loss :: 395.03 and the validation loss is ::456.91
# #------------------  saving the model in 277 epoch with validation loss :: 456.91
# Epoch 278	 train loss :: 392.80 and the validation loss is ::473.00
# Epoch 279	 train loss :: 391.27 and the validation loss is ::463.45
# Epoch 280	 train loss :: 390.77 and the validation loss is ::454.13
# #------------------  saving the model in 280 epoch with validation loss :: 454.13
# Epoch 281	 train loss :: 393.40 and the validation loss is ::457.49
# Epoch 282	 train loss :: 390.54 and the validation loss is ::456.17
# Epoch 283	 train loss :: 391.62 and the validation loss is ::462.08
# Epoch 284	 train loss :: 392.27 and the validation loss is ::462.39
# Epoch 285	 train loss :: 393.20 and the validation loss is ::455.50
# Epoch 286	 train loss :: 391.20 and the validation loss is ::459.74
# Epoch 287	 train loss :: 390.96 and the validation loss is ::465.56
# Epoch 288	 train loss :: 391.93 and the validation loss is ::454.34
# Epoch 289	 train loss :: 392.86 and the validation loss is ::452.71
# #------------------  saving the model in 289 epoch with validation loss :: 452.71
# Epoch 290	 train loss :: 391.57 and the validation loss is ::455.96
# Epoch 291	 train loss :: 391.73 and the validation loss is ::452.91
# Epoch 292	 train loss :: 392.03 and the validation loss is ::460.46
# Epoch 293	 train loss :: 389.05 and the validation loss is ::453.71
# Epoch 294	 train loss :: 392.75 and the validation loss is ::452.30
# #------------------  saving the model in 294 epoch with validation loss :: 452.30
# Epoch 295	 train loss :: 393.90 and the validation loss is ::466.80
# Epoch 296	 train loss :: 389.90 and the validation loss is ::455.08
# Epoch 297	 train loss :: 392.06 and the validation loss is ::455.91
# Epoch 298	 train loss :: 391.06 and the validation loss is ::455.18
# Epoch 299	 train loss :: 391.05 and the validation loss is ::458.69
# Epoch 300	 train loss :: 394.24 and the validation loss is ::455.36
# Epoch 301	 train loss :: 391.07 and the validation loss is ::453.75
# Epoch 302	 train loss :: 391.27 and the validation loss is ::453.44
# Epoch 303	 train loss :: 393.29 and the validation loss is ::457.09
# Epoch 304	 train loss :: 391.87 and the validation loss is ::454.40
# Epoch 305	 train loss :: 388.03 and the validation loss is ::452.26
# #------------------  saving the model in 305 epoch with validation loss :: 452.26
# Epoch 306	 train loss :: 391.03 and the validation loss is ::455.21
# Epoch 307	 train loss :: 390.87 and the validation loss is ::451.70
# #------------------  saving the model in 307 epoch with validation loss :: 451.70
# Epoch 308	 train loss :: 391.66 and the validation loss is ::453.03
# Epoch 309	 train loss :: 391.36 and the validation loss is ::450.03
# #------------------  saving the model in 309 epoch with validation loss :: 450.03
# Epoch 310	 train loss :: 390.38 and the validation loss is ::453.35
# Epoch 311	 train loss :: 390.09 and the validation loss is ::460.26
# Epoch 312	 train loss :: 393.03 and the validation loss is ::460.57
# Epoch 313	 train loss :: 388.06 and the validation loss is ::468.57
# Epoch 314	 train loss :: 390.68 and the validation loss is ::453.52
# Epoch 315	 train loss :: 388.44 and the validation loss is ::451.62
# Epoch 316	 train loss :: 389.56 and the validation loss is ::454.58
# Epoch 317	 train loss :: 388.27 and the validation loss is ::456.72
# Epoch 318	 train loss :: 388.97 and the validation loss is ::453.24
# Epoch 319	 train loss :: 387.95 and the validation loss is ::456.85
# Epoch 320	 train loss :: 389.98 and the validation loss is ::451.88
# Epoch 321	 train loss :: 387.66 and the validation loss is ::451.11
# Epoch 322	 train loss :: 392.26 and the validation loss is ::451.38
# Epoch 323	 train loss :: 388.37 and the validation loss is ::454.41
# Epoch 324	 train loss :: 387.56 and the validation loss is ::452.83
# Epoch 325	 train loss :: 388.32 and the validation loss is ::453.34
# Epoch 326	 train loss :: 387.68 and the validation loss is ::453.95
# Epoch 327	 train loss :: 388.34 and the validation loss is ::451.33
# Epoch 328	 train loss :: 388.89 and the validation loss is ::456.10
# Epoch 329	 train loss :: 387.65 and the validation loss is ::455.47
# Epoch 330	 train loss :: 387.89 and the validation loss is ::451.43
# Epoch 331	 train loss :: 389.85 and the validation loss is ::461.79
# Epoch 332	 train loss :: 390.39 and the validation loss is ::451.87
# Epoch 333	 train loss :: 386.05 and the validation loss is ::455.95
# Epoch 334	 train loss :: 388.47 and the validation loss is ::456.28
# Epoch 335	 train loss :: 386.95 and the validation loss is ::449.82
# #------------------  saving the model in 335 epoch with validation loss :: 449.82
# Epoch 336	 train loss :: 387.79 and the validation loss is ::450.81
# Epoch 337	 train loss :: 388.08 and the validation loss is ::451.17
# Epoch 338	 train loss :: 388.16 and the validation loss is ::449.25
# #------------------  saving the model in 338 epoch with validation loss :: 449.25
# Epoch 339	 train loss :: 389.26 and the validation loss is ::449.99
# Epoch 340	 train loss :: 385.98 and the validation loss is ::450.60
# Epoch 341	 train loss :: 388.43 and the validation loss is ::450.54
# Epoch 342	 train loss :: 387.95 and the validation loss is ::453.36
# Epoch 343	 train loss :: 387.74 and the validation loss is ::448.51
# #------------------  saving the model in 343 epoch with validation loss :: 448.51
# Epoch 344	 train loss :: 389.44 and the validation loss is ::449.45
# Epoch 345	 train loss :: 388.29 and the validation loss is ::454.90
# Epoch 346	 train loss :: 386.99 and the validation loss is ::451.48
# Epoch 347	 train loss :: 385.86 and the validation loss is ::456.39
# Epoch 348	 train loss :: 386.69 and the validation loss is ::452.65
# Epoch 349	 train loss :: 387.42 and the validation loss is ::449.98

# %% [markdown]
# make some plots

# %%
plt.plot(range(len(valid_loss)),valid_loss,label = "Validation loss")
plt.plot(range(len(train_loss)),train_loss,label = "training loss")
plt.legend(loc='center left')

# %% [markdown]
# now it's time to test our model on the training test, we will start by loading our saved model (in case it change after the last saving time)

# %%
model_v1.load_state_dict(torch.load(saved_file_name,map_location='cpu'))
# Out:
# <All keys matched successfully>

# %%
def print_statistics(statistics):
    ### printing
    total = statistics[1][1]+statistics[1][0]+statistics[0][1]+statistics[0][0]
    print('\t ----------------------------------')
    print('tested with  :: {} \t accuracy was ::{:.2f}% \t detected positives :: {}/{} \t detected negatives :: {}/{}'.format(total,100 * ((statistics[1][1]+statistics[0][0])/total),statistics[1][1],statistics[1][1]+statistics[1][0],statistics[0][0],statistics[0][0]+statistics[0][1]))
    print('\t ----------------------------------')
    print("\t Confusion Matrix")
    print('True Positive \t {}'.format(statistics[1][1]))
    print('False Negative\t {}'.format(statistics[0][1]))    
    print('False Positive\t {}'.format(statistics[1][0]))    
    print('True Negative \t {}'.format(statistics[0][0]))
    
    print("\t  Precision and Recall")
    print('Precision  {:.3f}\t'.format(statistics[1][1]/(statistics[1][1] + statistics[1][0])))
    print('Recall     {:.3f}\t'.format(statistics[1][1]/(statistics[1][1] + statistics[0][1])))

# %%
loss,accuracy,statistics = testing(model_v1,data_loaders['test_1'],criterion,False)
print_statistics(statistics)
# Out:
# 	 ----------------------------------
# tested with  :: 7628 	 accuracy was ::89.33% 	 detected positives :: 238/797 	 detected negatives :: 6576/6831
# 	 ----------------------------------
# 	 Confusion Matrix
# True Positive 	 238
# False Negative	 255
# False Positive	 559
# True Negative 	 6576
# 	  Precision and Recall
# Precision  0.299
# Recall     0.483

# %%
loss,accuracy,statistics = testing(model_v1,data_loaders['test_2'],criterion,False)
print_statistics(statistics)
# Out:
# 	 ----------------------------------
# tested with  :: 32101 	 accuracy was ::86.59% 	 detected positives :: 21513/22619 	 detected negatives :: 6284/9482
# 	 ----------------------------------
# 	 Confusion Matrix
# True Positive 	 21513
# False Negative	 3198
# False Positive	 1106
# True Negative 	 6284
# 	  Precision and Recall
# Precision  0.951
# Recall     0.871

# %% [markdown]
# # <a id="window">Window slider</a>
# in this part we will try to detect faces in a picture where there is different faces in a different sizes, we will use a what we call a widnow slider, it's a window 64*64 but in different sizes of the same image.
#
#
# * in the first slinding operation we will use an image of a closer size to the original one
# * in the second operation we will reduce the size of oue image by 20% if it's prevuois size
# * in the 3ed operation we will repeat the 2nd operation
#
# after each operation we collect these sub imgaes and we try to predict if the probabilty of the existing of a face by using our model.****

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# read the image and define the stepSize and window size 
# (width,height)


def window_sliding(pic_name = "../input/justpeople/happy_young_people2.jpg",window_size =(64,64),step_size = 10,iterations = 3, pic_reducing = 0.2):
    threshold = 0.8
    model_v1.to('cpu')
    image = cv2.imread(pic_name) # your image path
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    h = (image.shape[0] // window_size[0])
    w = (image.shape[1] // window_size[1])
    
    windows =list()
    win__ = list()
    for i in range(iterations):
        
        h = int(h * (1 - i * pic_reducing )) 
        w = int(w * (1 - i * pic_reducing ))
        temp = cv2.resize(image, (w * window_size[1],h * window_size[0]), interpolation = cv2.INTER_LINEAR)
        for x in range(0, image.shape[1]  , step_size):
            for y in range(0, image.shape[0] , step_size):
                window ={"image":temp[x:x + window_size[1], y:y + window_size[0]],
                         "location": ([x,x + window_size[1]], [y,y + window_size[0]]),
                         "pic_reducing": i * pic_reducing
                         }
                # test if it contines a face or not in the same time 
                sub_image =  torch.tensor(window['image'])#.transpose((2,0,1))).unsqueeze(0)
                try:
                    sub_image = transforms.ToPILImage()(sub_image)
                    a = images_transform["test"](sub_image)
                    result = model_v1(a.float().unsqueeze(0))
                    win__.append(window)
                    if result[0,1] > threshold:
                        window['probabily'] = result[0,1]
                        windows.append(window)
                        
                except:
                    pass
    return image,windows,win__

# %% [markdown]
# so now after creating our function, we will use it and print the results

# %%
image, boxes,_ = window_sliding()
print(len(boxes))
# Out:
# 344

# %%
im = _[297]['image']
plt.subplot(1, 3, 1)
plt.imshow(im )
sub_image =  torch.tensor(im)
sub_image = transforms.ToPILImage()(sub_image)
sub_image = transforms.Grayscale(num_output_channels=1)(sub_image)

a = images_transform["test"](sub_image)
plt.subplot(1, 3, 2)
plt.imshow(a.squeeze(), cmap='gray')
print(a.size())
result = model_v1(a.float().unsqueeze(0))
print(result)
# Out:
# torch.Size([1, 64, 64])
# tensor([[1.0000e+00, 8.0512e-11]], grad_fn=<SoftmaxBackward>)

# %%
import matplotlib.patches as patches
im = np.array(np.array(image).astype('uint8'))

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Create a Rectangle patch
for i in boxes:
    rect = patches.Rectangle((i['location'][1][0] * (1 + i['pic_reducing']) ,
                              i['location'][0][0] * (1+ i['pic_reducing'])),
                             int(64 * (1 + i['pic_reducing'])),
                             int(64 * (1 + i['pic_reducing'])),
                             linewidth=1,edgecolor='r',facecolor='none')
    # add the boxes to the image
    ax.add_patch(rect)

plt.show()

# %% [markdown]
# # Non-Max suppression

# %% [markdown]
# in this phase we will try to get rid of some overlapped boxes by deleting the overlapped one with the lower probability.

# %%
threshold = 0.5
remove = list()
for i in range(len(boxes)):
    for j in range(i+1,len(boxes)):
        if j not in remove:
            y = abs(boxes[i]['location'][1][0] - boxes[j]['location'][1][0])
            x = abs(boxes[i]['location'][0][0] - boxes[j]['location'][0][0])
            result = ((x<=64)*(y<=64)*((64 - x) + (64 - y)))/ (64 * 2)
            if result >= threshold:
                if boxes[i]['probabily']> boxes[j]['probabily']:
                    remove.append(j)
                else:
                    remove.append(i)
                    break
# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Create a Rectangle patch
for j,i in enumerate(boxes):
    if j not in remove:
        rect = patches.Rectangle((int(i['location'][1][0] * (1 + i['pic_reducing'])), 
                                  int(i['location'][0][0]) * (1 + i['pic_reducing']))
                                 ,int(64 * (1 + i['pic_reducing'])),
                                 int(64 * (1 + i['pic_reducing'])),
                                 linewidth=1,edgecolor='r',facecolor='none')
        ax.add_patch(rect)
# Add the patch to the Axes


plt.show()
